# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing.text import Tokenizer
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout,Embedding,LSTM,Conv1D, MaxPooling1D, Flatten
from sklearn.preprocessing import LabelBinarizer
import sklearn.datasets as skds
from pathlib import Path

# %%
df=pd.read_csv('/kaggle/input/financial-sentiment-analysis/data.csv',usecols=['Sentence'])
df
# Out:
#                                                Sentence
# 0     The GeoSolutions technology will leverage Bene...
# 1     $ESI on lows, down $1.50 to $2.50 BK a real po...
# 2     For the last quarter of 2010 , Componenta 's n...
# 3     According to the Finnish-Russian Chamber of Co...
# 4     The Swedish buyout firm has sold its remaining...
# ...                                                 ...
# 5837  RISING costs have forced packaging producer Hu...
# 5838  Nordic Walking was first used as a summer trai...
# 5839  According shipping company Viking Line , the E...
# 5840  In the building and home improvement trade , s...
# 5841  HELSINKI AFX - KCI Konecranes said it has won ...
#
# [5842 rows x 1 columns]

# %%
df.drop_duplicates(subset='Sentence',inplace=True)
df
# Out:
#                                                Sentence
# 0     The GeoSolutions technology will leverage Bene...
# 1     $ESI on lows, down $1.50 to $2.50 BK a real po...
# 2     For the last quarter of 2010 , Componenta 's n...
# 3     According to the Finnish-Russian Chamber of Co...
# 4     The Swedish buyout firm has sold its remaining...
# ...                                                 ...
# 5835  HSBC Says Unit to Book $585 Million Charge on ...
# 5836  Daily Mail parent company in talks with potent...
# 5838  Nordic Walking was first used as a summer trai...
# 5839  According shipping company Viking Line , the E...
# 5841  HELSINKI AFX - KCI Konecranes said it has won ...
#
# [5322 rows x 1 columns]

# %%
from textblob import TextBlob


df[['Polarity', 'Subjectivity']] = df['Sentence'].apply(lambda Text: pd.Series(TextBlob(Text).sentiment))

# %%
df
# Out:
#                                                Sentence  Polarity  \
# 0     The GeoSolutions technology will leverage Bene...  0.209091
# 1     $ESI on lows, down $1.50 to $2.50 BK a real po...  0.022222
# 2     For the last quarter of 2010 , Componenta 's n...  0.000000
# 3     According to the Finnish-Russian Chamber of Co...  0.062500
# 4     The Swedish buyout firm has sold its remaining... -0.100000
# ...                                                 ...       ...
# 5835  HSBC Says Unit to Book $585 Million Charge on ...  0.000000
# 5836  Daily Mail parent company in talks with potent...  0.000000
# 5838  Nordic Walking was first used as a summer trai...  0.250000
# 5839  According shipping company Viking Line , the E...  0.187500
# 5841  HELSINKI AFX - KCI Konecranes said it has won ...  0.250000
#
#       Subjectivity
# 0         0.588636
# 1         0.294444
# 2         0.172917
# 3         0.500000
# 4         0.233333
# ...            ...
# 5835      0.000000
# 5836      0.500000
# 5838      0.333333
# 5839      0.437500
# 5841      0.850000
#
# [5322 rows x 3 columns]

# %%
y = df['Polarity']
positive = 0
negative = 0
neutral = 0

for a in y:
    if a>0:
     positive=positive+1
    elif a<0:
     negative=negative+1
    else:
     neutral=neutral+1
numberOfTweetsAnalysed= positive+negative+neutral
print('Number of Tweets Analysed = '+str(numberOfTweetsAnalysed))
print('Positive tweets = '+str(positive))
print('Negative tweets = '+str(negative))
print('Neutral tweets = '+str(neutral))
# Out:
# Number of Tweets Analysed = 5322
# Positive tweets = 1703
# Negative tweets = 847
# Neutral tweets = 2772

# %%
plt.bar(['Positive','Negative','Neutral'],[positive,negative,neutral],color=['yellow','red','purple'])
plt.title("Datas")
plt.xlabel(" Sentiment")
plt.ylabel("Total Datas")
plt.show()

# %%
plt.pie([positive,negative,neutral], labels=['positive','Negative','Neutral'], autopct='%1.1f%%', startangle=40)
plt.title("Data Proportion ")
plt.show()

# %%
import spacy
import re,string
from nltk.corpus import stopwords
nlp = spacy.load('en_core_web_sm')
def preprocess(texts):
    doc = nlp(texts)
    text=" " .join([token.lemma_ for token in doc])
    text=' '.join(word for word in text.split() if word.lower() not in stopwords.words('english'))
    text = re.sub(r'\&\w*;','',text)
    text = re.sub('@[^\s]+','',text)
    text = re.sub(r'\$\w*','',text)
    text = text.lower()
    text = re.sub(r'https?:\/\/.*\/\w*','',text)
    text = re.sub(r'#\w*','',text)
    text = re.sub(r'[' + string.punctuation.replace('@','') + ']+',' ',text)
    text = re.sub(r'\b\w{1,2}\b','',text)
    text = re.sub(r'\s\s+',' ',text)
    text = re.sub("[^a-zA-Z]", " ", text)
    text=re.sub(r'\s+', ' ', text)
    text = text.lstrip(' ')
    text = ''.join(c for c in text if c <= '\uFFFF')
    return text

# %%
df['Sentence']=df['Sentence'].apply(lambda x:preprocess(x))

# %%
df
# Out:
#                                                Sentence  Polarity  \
# 0     geosolutions technology leverage benefon gps s...  0.209091
# 1                              esi low real possibility  0.022222
# 2     last quarter componenta net sale double eur eu...  0.000000
# 3     accord finnish russian chamber commerce major ...  0.062500
# 4     swedish buyout firm sell remain percent stake ... -0.100000
# ...                                                 ...       ...
# 5835       hsbc say unit book million charge settlement  0.000000
# 5836  daily mail parent company talk potential partn...  0.000000
# 5838  nordic walking first use summer training metho...  0.250000
# 5839  accord shipping company viking line decision s...  0.187500
# 5841  helsinki afx kci konecranes say win order four...  0.250000
#
#       Subjectivity
# 0         0.588636
# 1         0.294444
# 2         0.172917
# 3         0.500000
# 4         0.233333
# ...            ...
# 5835      0.000000
# 5836      0.500000
# 5838      0.333333
# 5839      0.437500
# 5841      0.850000
#
# [5322 rows x 3 columns]

# %%
data=df

# %%
from textblob import TextBlob


data[['Polarity', 'Subjectivity']] = data['Sentence'].apply(lambda Text: pd.Series(TextBlob(Text).sentiment))

# %%
y = data['Polarity']
positive = 0
negative = 0
neutral = 0

for a in y:
    if a>0:
     positive=positive+1
    elif a<0:
     negative=negative+1
    else:
     neutral=neutral+1
numberOfTweetsAnalysed= positive+negative+neutral
print('Number of Tweets Analysed = '+str(numberOfTweetsAnalysed))
print('Positive tweets = '+str(positive))
print('Negative tweets = '+str(negative))
print('Neutral tweets = '+str(neutral))
# Out:
# Number of Tweets Analysed = 5322
# Positive tweets = 1719
# Negative tweets = 761
# Neutral tweets = 2842

# %% [markdown]
# #### We use the DataFrame that has been processed with TextBlob and preprocessed, instead of the DataFrame that is preprocessed and then analyzed with TextBlob.

# %%
df
# Out:
#                                                Sentence  Polarity  \
# 0     geosolutions technology leverage benefon gps s...  0.209091
# 1                              esi low real possibility  0.100000
# 2     last quarter componenta net sale double eur eu...  0.025000
# 3     accord finnish russian chamber commerce major ...  0.031250
# 4     swedish buyout firm sell remain percent stake ... -0.100000
# ...                                                 ...       ...
# 5835       hsbc say unit book million charge settlement  0.000000
# 5836  daily mail parent company talk potential partn...  0.000000
# 5838  nordic walking first use summer training metho...  0.125000
# 5839  accord shipping company viking line decision s...  0.187500
# 5841  helsinki afx kci konecranes say win order four...  0.525000
#
#       Subjectivity
# 0         0.588636
# 1         0.300000
# 2         0.091667
# 3         0.250000
# 4         0.233333
# ...            ...
# 5835      0.000000
# 5836      0.500000
# 5838      0.166667
# 5839      0.437500
# 5841      0.625000
#
# [5322 rows x 3 columns]

# %%
df['category'] = df['Polarity'].apply(lambda x: 'Negative' if x < 0 else 'Positive' if x > 0 else 'Neutral')

# %%
print(set(df['category']))
# Out:
# {'Neutral', 'Negative', 'Positive'}

# %%
# # lets take 80% data as training and remaining 20% for test.
# train_size = int(len(df) * .8)

# train_posts = df['Sentence'][:train_size]
# train_tags = df['category'][:train_size]


# test_posts = df['Sentence'][train_size:]
# test_tags = df['category'][train_size:]

from sklearn.model_selection import train_test_split
train_df, test_df = train_test_split(df, test_size=0.30, random_state=42,shuffle=True)

# Extract sentences and categories from the training set
train_posts = train_df['Sentence']
train_tags = train_df['category']

# Extract sentences and categories from the test set
test_posts = test_df['Sentence']
test_tags = test_df['category']

# %%
num_labels = 3
vocab_size = 1500
batch_size = 64

# define Tokenizer with Vocab Size
tokenizer = Tokenizer(num_words=vocab_size)
tokenizer.fit_on_texts(train_posts)

x_train = tokenizer.texts_to_matrix(train_posts, mode='tfidf')

x_test = tokenizer.texts_to_matrix(test_posts, mode='tfidf')
encoder = LabelBinarizer()
encoder.fit(train_tags)
y_train = encoder.transform(train_tags)
y_test = encoder.transform(test_tags)

# %%
num_labels=3
# embedding_dim=100

# model=Sequential()
# model.add(Embedding(input_dim=vocab_size,output_dim=embedding_dim,input_length=1500))
# # model.add(Conv1D(filters=128,kernel_size=3,activation='relu',padding='same'))
# model.add(LSTM(units=8,return_sequences=True,dropout=0.25,recurrent_dropout=0.3))
# model.add(LSTM(units=4,dropout=0.25,recurrent_dropout=0.3))
# # model.add(Flatten())
# model.add(Dense(8, activation='relu'))

# model.add(Dense(num_labels))
# model.add(Activation('softmax'))
# model.summary()
embedding_dim=50
model=Sequential()
model.add(Embedding(input_dim=vocab_size,output_dim=embedding_dim,input_length=1500))
model.add(Conv1D(filters=16,kernel_size=3,activation='relu',padding='same'))
model.add(LSTM(units=50,return_sequences=True))
model.add(Conv1D(filters=8,kernel_size=3,activation='relu',padding='same'))

model.add(LSTM(units=10))
model.add(Dropout(0.3))

model.add(Dense(16,activation='relu'))
model.add(Dense(18,activation='relu'))

model.add(Dense(num_labels, activation="softmax"))
model.summary()
# Out:
# Model: "sequential_52"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_51 (Embedding)    (None, 1500, 50)          75000
#
#  conv1d_51 (Conv1D)          (None, 1500, 16)          2416
#
#  lstm_111 (LSTM)             (None, 1500, 50)          13400
#
#  conv1d_52 (Conv1D)          (None, 1500, 8)           1208
#
#  lstm_112 (LSTM)             (None, 10)                760
#
#  dropout_24 (Dropout)        (None, 10)                0
#
#  dense_106 (Dense)           (None, 16)                176
#
#  dense_107 (Dense)           (None, 18)                306
#
#  dense_108 (Dense)           (None, 3)                 57
#
# =================================================================
# Total params: 93323 (364.54 KB)
# Trainable params: 93323 (364.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from keras.optimizers import Adam, RMSprop
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau


checkpoint = ModelCheckpoint("nlp_model.h5",
                             monitor="val_loss",
                             mode="min",
                             save_best_only=True,
                             verbose=1)

earlystop = EarlyStopping(monitor='val_loss',
                          min_delta=0,
                          patience=2,
                          verbose=3,
                          restore_best_weights=True)

reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.001,
                              patience=1,
                              verbose=1,
                              min_delta=0.001)

# Callback list
callbacks = [earlystop, checkpoint, reduce_lr]

# Compilation
model.compile(loss='categorical_crossentropy',
                  optimizer=Adam(lr=0.001),
                  metrics=['accuracy'])


history = model.fit(x_train,y_train,
                    batch_size = batch_size,
                    epochs = 5,
                    verbose = 1,
                    callbacks=callbacks,
                    validation_split = 0.1)
# Out:
# Epoch 1/5
# 53/53 [==============================] - ETA: 0s - loss: 0.9858 - accuracy: 0.5382
# Epoch 1: val_loss improved from inf to 1.01820, saving model to nlp_model.h5
# 53/53 [==============================] - 12s 117ms/step - loss: 0.9858 - accuracy: 0.5382 - val_loss: 1.0182 - val_accuracy: 0.4853 - lr: 0.0010
# Epoch 2/5
# 53/53 [==============================] - ETA: 0s - loss: 0.9758 - accuracy: 0.5382
# Epoch 2: val_loss did not improve from 1.01820
#
# Epoch 2: ReduceLROnPlateau reducing learning rate to 1.0000000474974512e-06.
# 53/53 [==============================] - 5s 95ms/step - loss: 0.9758 - accuracy: 0.5382 - val_loss: 1.0209 - val_accuracy: 0.4853 - lr: 0.0010
# Epoch 3/5
# 53/53 [==============================] - ETA: 0s - loss: 0.9781 - accuracy: 0.5382Restoring model weights from the end of the best epoch: 1.
#
# Epoch 3: val_loss did not improve from 1.01820
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-10.
# 53/53 [==============================] - 5s 89ms/step - loss: 0.9781 - accuracy: 0.5382 - val_loss: 1.0209 - val_accuracy: 0.4853 - lr: 1.0000e-06
# Epoch 3: early stopping

# %% [markdown]
# # Loss Chart

# %%
import matplotlib.pyplot as plt

history_dict = history.history
plt.plot(history_dict['loss'])
plt.plot(history_dict['val_loss'])
plt.legend(['Training_loss','Validation_Loss'])
plt.xlabel("Epoch")
plt.ylabel("loss")

plt.title("Loss Chart")
plt.show()

# %% [markdown]
# # Accuracy Chart

# %%
import matplotlib.pyplot as plt

history_dict = history.history
plt.plot(history_dict['accuracy'])
plt.plot(history_dict['val_accuracy'])
plt.legend(['Training_Accuracy','Validation_Accuracy'])
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Accuracy Chart")
plt.show()

# %%
text_labels=encoder.classes_
print("These are categories",text_labels)


for i in range(0,100): #range can be any number suitable to the range of the dataset
    prediction = model.predict(np.array([x_test[i]])) #we have changed news data to numpy array to fit the requirements of the predict function
    predicted_label = text_labels[np.argmax(prediction[0])] #argmax
    # print(predicted_label)
    print(test_posts.iloc[i])
    # print(test_files_names.iloc[i])
    # print(prediction)
    print('Actual label:' + test_tags.iloc[i])
    print("Predicted label: " + predicted_label)
    print(prediction)
# Out:
# These are categories ['Negative' 'Neutral' 'Positive']
# 1/1 [==============================] - 1s 815ms/step
# lead private road ambulance service company finland
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 54ms/step
# finnish silicon wafer manufacturer okmetic oyj say swing net profit mln euro mln first nine month net loss mln euro mln year early
# Actual label:Positive
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 58ms/step
# gild expand research facility keep pace innovation
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 53ms/step
# number one mean create add value stakeholder everything
# Actual label:Negative
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 52ms/step
# operate profit eur compare eur
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.3369868 ]]
# 1/1 [==============================] - 0s 53ms/step
# googl set day move average
# Actual label:Negative
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 54ms/step
# morrison finance chief fill gap ceo leave early
# Actual label:Positive
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 55ms/step
# swedish subsidiary hold net smelter return nsr royalty two advanced copper project northern sweden viscaria adak projects develop avalon minerals ltd asx avi
# Actual label:Positive
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 53ms/step
# omx helsinki pct low omx helsinki pct volume mln eur
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 56ms/step
# hcp come party buy gonna give solid gain dividend
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.3369868 ]]
# 1/1 [==============================] - 0s 53ms/step
# also strong asset electronic medium employ increase percent last year
# Actual label:Positive
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 53ms/step
# earning per share eps see eur eur
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 51ms/step
# vike line manage well current ferry
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 53ms/step
# pretax loss total eur profit eur
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 51ms/step
# share still subscribe series share option max
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 54ms/step
# full function weigh kilogram measure slightly two centimeter thin
# Actual label:Negative
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 53ms/step
# ocwen reach settlement california regulator
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 55ms/step
# agreement expand tekla structures scope use bridge design
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748257 0.5155307  0.33698675]]
# 1/1 [==============================] - 0s 55ms/step
# capman haavisto responsible group finances accounting
# Actual label:Positive
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 51ms/step
# operate profit total eur net sale
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 53ms/step
# cost saving rise mln eur year oko say
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 53ms/step
# elsewhere tendency towards developed packaging
# Actual label:Positive
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 51ms/step
# ova press stake joint venture imsm hold stake
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 54ms/step
# company net sale eur pre tax profit eur
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 56ms/step
# nordea see return positive growth baltic country
# Actual label:Positive
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 54ms/step
# tieto service also use send process receive material relate absentee voting
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.3369868 ]]
# 1/1 [==============================] - 0s 51ms/step
# news feedschroders book solid earning growth several board change
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 54ms/step
# danske bank denmark large bank million customer
# Actual label:Positive
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.3369868 ]]
# 1/1 [==============================] - 0s 54ms/step
# inventor mukkavilli krishna kiran sabharwal ashutosh aazhang behnaam
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.3369868 ]]
# 1/1 [==============================] - 0s 55ms/step
# finnish dental care group oral hammaslaakarit oyj post total net profit euro mln first nine month versus net loss euro period
# Actual label:Positive
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 53ms/step
# group also strong global position fishing category
# Actual label:Positive
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 53ms/step
# kone net sale rise year year first nine month
# Actual label:Positive
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 53ms/step
# follow registration number issue outstanding share basware
# Actual label:Positive
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.3369868 ]]
# 1/1 [==============================] - 0s 53ms/step
# finnish food industry company ruokatalo atria form joint venture company call nsi kalkkuna produce turkey meat
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14846386 0.51415855 0.33737755]]
# 1/1 [==============================] - 0s 53ms/step
# operate loss increase eur mn loss eur
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 51ms/step
# via move company aim annual saving eur million usd main part expect realize year
# Actual label:Positive
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 52ms/step
# adpnews sep finnish silicon wafer maker okmetic oyj hel okm v say reduce number clerical worker worldwide result personnel negotiation complete today
# Actual label:Positive
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 52ms/step
# purchase sum eur mn
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 54ms/step
# compare ftse index fall point day relative price change
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 54ms/step
# end last week protalix biotherapeutics inc amex plx publish prospectus first offering amex share capital
# Actual label:Positive
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 53ms/step
# basic banking activity continue normal
# Actual label:Positive
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 54ms/step
# beijing xfn asia hong kong list standard chartered bank say sign china mobile phone dealer financing agreement nokia make first foreign bank offer financing country small medium enterprise
# Actual label:Negative
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 55ms/step
# lay succeed walter nter base finland
# Actual label:Negative
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 53ms/step
# omx market forward mature may novator finland direct shareholding amer sports corporation exceed one fifth company share voting right
# Actual label:Positive
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.3369868 ]]
# 1/1 [==============================] - 0s 53ms/step
# report net sale approximately eur mn
# Actual label:Negative
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 53ms/step
# finnish department store group stockmann plan acquire eur mn direct issue right offering
# Actual label:Positive
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.3369868 ]]
# 1/1 [==============================] - 0s 50ms/step
# dealer say share largely hit investor disappointment refining margin usd per barrel quarter performance shipping unit see ebit drop mln eur mln eur year amid fall volume tanker rate
# Actual label:Negative
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 52ms/step
# standard chartered shifts emerging markets strategy loss
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 54ms/step
# adjust change group structure division net sale increase
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.3369868 ]]
# 1/1 [==============================] - 0s 54ms/step
# amzn trailing month operate cash flow rise billion free cash flow decrease million
# Actual label:Positive
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 53ms/step
# cat hangin thread click away cliff drop need follow snap back vix
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.3369868 ]]
# 1/1 [==============================] - 0s 58ms/step
# biohit oyj develop manufacture market liquid handling product diagnostic test system use research healthcare industrial laboratory
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.3369868 ]]
# 1/1 [==============================] - 0s 53ms/step
# small long via call
# Actual label:Negative
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 55ms/step
# grid show dia cap long term range any rally beyond today level range lead meltdown
# Actual label:Negative
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 60ms/step
# combine exist solution single platform comptel say reduce cost deployment
# Actual label:Negative
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.3369868 ]]
# 1/1 [==============================] - 0s 56ms/step
# goog breakout likely medium target
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.3369868 ]]
# 1/1 [==============================] - 0s 56ms/step
# work include laying natural stone pavement installation underground heating surface water drainage system
# Actual label:Positive
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 56ms/step
# adp news oct finnish food company raisio oyj omx raivv say today net profit jump eur million usd first nine month eur million period
# Actual label:Positive
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 54ms/step
# sainsbury cfo rogers replace home retail ceo walden
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.3369868 ]]
# 1/1 [==============================] - 0s 57ms/step
# cooperation airbaltic expect lead transfer finncomm ownership airbaltic time
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 58ms/step
# city invite however public procurement tender tailor make public furniture park bench litter receptacle public toilet well bus shelter street light
# Actual label:Positive
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 57ms/step
# join rautakirja lead one four business area take position president ceo
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 54ms/step
# accord chairman michael hornborg organization merely criticise raisio weak performance
# Actual label:Negative
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 66ms/step
# tesla motors recall model suv tsla
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 56ms/step
# protalix close friday american stock exchange give market cap million
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 55ms/step
# bac adsk nflx long morning
# Actual label:Negative
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 52ms/step
# delivery nokia nokia nokia expect start second quarter
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 71ms/step
# upm kymmene generate four consecutive quarter positive free cash flow
# Actual label:Positive
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.3369868 ]]
# 1/1 [==============================] - 0s 55ms/step
# tsla steaming stock relentless moment
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.3369868 ]]
# 1/1 [==============================] - 0s 54ms/step
# operate profit decrease nearly eur however
# Actual label:Positive
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 56ms/step
# bbry hearing rumour major joint venture announcement
# Actual label:Positive
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 56ms/step
# helsinki afx outokumpu say technology unit win mln eur contract bosnia herzegovina aluminij mostar upgrade anode plant
# Actual label:Positive
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 56ms/step
# utah capital want next headquarters amer sports corp ski equipment company
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 54ms/step
# aviva promise high dividend boost flagging share price
# Actual label:Positive
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 53ms/step
# major brewery increase domestic beer sale per cent last year million litre million litre
# Actual label:Positive
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 51ms/step
# swiss bank credit suisse international act investor locomotive manufacturing plant astana administration say
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 54ms/step
# aapl weekly still move average create lower high
# Actual label:Positive
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.3369868 ]]
# 1/1 [==============================] - 0s 53ms/step
# green day
# Actual label:Negative
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 51ms/step
# prlb hang tough market due analyst upgrade last week almost
# Actual label:Negative
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 54ms/step
# release offer security sale united states elsewhere
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 53ms/step
# operate profit month period decrease eur net sale increase eur compare
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.3369868 ]]
# 1/1 [==============================] - 0s 53ms/step
# gross area innova project
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 50ms/step
# ship unloader totally enclose along entire conveying line storage facility
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 52ms/step
# britain ftse gain land securities dividend hike
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 52ms/step
# london afx european broker recommendation issue today collate afx news range market source
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 55ms/step
# jeder beta tester erh lt kostenlos sechs monate lang updates und hat laut eigener aussage die glichkeit die finale version beeinflussen
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.3369868 ]]
# 1/1 [==============================] - 0s 57ms/step
# april finnish construction engineering company outotec oyj hel ote v say today slip net loss eur first quarter net profit eur corresponding period last year
# Actual label:Positive
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 56ms/step
# answer question many visitor conversation get big team problem set social medium channel
# Actual label:Positive
# Predicted label: Neutral
# [[0.14748208 0.5155313  0.33698663]]
# 1/1 [==============================] - 0s 53ms/step
# sds pick speed may call
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 53ms/step
# part transaction nekoski paper mill remain real ownership continue galerie art production sappi long term contract
# Actual label:Positive
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 54ms/step
# forecast
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 53ms/step
# potential defect third row seat belt tesla motors recall model suv tsla
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 55ms/step
# bovine slaughter cut kuopio facility transfer kauhajoki slaughterhouse
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 56ms/step
# companiesmeggitt profit hit weak energy military market
# Actual label:Negative
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 54ms/step
# company plan increase unit specialist staff several dozen depend market situation
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 55ms/step
# notable gainer among liquid option name morning include stx nem wdc gme
# Actual label:Positive
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.3369868 ]]
# 1/1 [==============================] - 0s 56ms/step
# agreement pfizer fund biotie research activity pde phosphodiesterase inhibitor program since start late sole authority develop discover compound
# Actual label:Negative
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.3369868 ]]
# 1/1 [==============================] - 0s 53ms/step
# operating profit net sale month period increase respectively eur eur compare financial year
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 54ms/step
# shell offer percent premium buy billion
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.33698684]]
# 1/1 [==============================] - 0s 56ms/step
# net profit period million euro
# Actual label:Neutral
# Predicted label: Neutral
# [[0.14748298 0.51553017 0.3369868 ]]

# %%
tex_labels=encoder.classes_

# %%
tex_labels
# Out:
# array(['Negative', 'Neutral', 'Positive'], dtype='<U8')
