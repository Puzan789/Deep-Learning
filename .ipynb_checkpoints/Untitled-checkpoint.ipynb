# %%
import pandas as pd
import cv2 
import matplotlib.pyplot as plt
import matplotlib.image as mpig

# %%
img=cv2.imread('earth.jpg')
cv2.imshow('imaged',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread('earth.jpg')
plt.imshow(img, cmap = 'gray')
plt.imshow(img)
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %%
img=mpig.imread('earth.jpg')
plt.imshow(img)
plt.xticks([])
plt.yticks([])
# Out:
# ([], [])

# %%
img = cv2.imread('earth.jpg',0)
plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
img=cv2.imread('earth.jpg')
cv2.imshow('iamgsie',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
r=img[:,:,0]
g=img[:,:,1]
b=img[:,:,2]
p,(ax1,ax2,ax3)=plt.subplots(1,3,figsize=(20,10)),plt.xticks([])
ax1.imshow(r)
ax2.imshow(g)
ax3.imshow(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 4
#       2 g=img[:,:,1]
#       3 b=img[:,:,2]
# ----> 4 p,(ax1,ax2,ax3)=plt.subplots(1,3,figsize=(20,10)),plt.xticks([])
#       5 ax1.imshow(r)
#       6 ax2.imshow(g)
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
reconstructed_image = np.stack([b, g, r], axis=-1)
plt.imshow(reconstructed_image)

# %%
cv2.imshow('iamges',b)
cv2.waitKey(0)
cv2.destroyAllWindows()
