# %%
import cv2 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
img=cv2.imread('image.jpg')
cv2.imshow('random',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img=cv2.imread('image.jpg')
plt.imshow(img,cmap='gray')
plt.xticks([]),plt.yticks([])
plt.show()

# %%
img
# Out:
# array([[[225, 198, 172],
#         [227, 200, 174],
#         [230, 200, 175],
#         ...,
#         [217, 135,  40],
#         [216, 136,  41],
#         [217, 137,  42]],
#
#        [[228, 201, 175],
#         [224, 196, 172],
#         [229, 198, 175],
#         ...,
#         [218, 136,  41],
#         [217, 137,  42],
#         [214, 134,  41]],
#
#        [[228, 201, 181],
#         [228, 198, 179],
#         [225, 196, 175],
#         ...,
#         [217, 137,  44],
#         [217, 137,  44],
#         [216, 136,  43]],
#
#        ...,
#
#        [[ 42,  77,  27],
#         [ 59, 101,  46],
#         [ 54, 109,  54],
#         ...,
#         [  6,  18,   0],
#         [ 27,  39,   3],
#         [ 68, 105,  55]],
#
#        [[ 54,  93,  37],
#         [ 41,  89,  31],
#         [ 24,  71,  22],
#         ...,
#         [ 20,  32,   2],
#         [ 59,  82,  37],
#         [ 81, 133,  73]],
#
#        [[ 39,  79,  21],
#         [ 32,  80,  14],
#         [  9,  43,   3],
#         ...,
#         [ 43,  68,  18],
#         [ 83, 128,  72],
#         [ 92, 149,  88]]], dtype=uint8)

# %%
b=img[:,:,0]
g=img[:,:,1]
r=img[:,:,2]
im=np.stack([r,g,b],axis=-1)
plt.imshow(im)
plt.show()

# %%
import matplotlib.image as mpimg

# %%
image=mpimg.imread('marigold.jpg')
r=image[:,:,0]
g=image[:,:,1]
b=image[:,:,2]
f,(ax1,ax2,ax3)=plt.subplots(1,3,figsize=(20,10))
ax1.imshow(r)
ax2.imshow(g)
ax3.imshow(b)
